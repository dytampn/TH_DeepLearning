# %% [markdown]
# <a href="https://colab.research.google.com/github/dytampn/TH_DeepLearning/blob/main/TH_DeepLearning_Tuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
import numpy as np
my_list = [1, 9, 15, 39]
print('Python list:', my_list)
my_numpy_array = np.array(my_list)
print('Numpy array:', my_numpy_array)
# Out:
# Python list: [1, 9, 15, 39]
# Numpy array: [ 1  9 15 39]

# %%
b = np.array([[1, 2, 3], [4, 5, 6]])
print(b)
print(b.shape)
print(b.dtype)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)
# int64
